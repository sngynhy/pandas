# %% [markdown]
# ## 정렬
# ### index명/컬럼명을 순 정렬
# - #### sort_index(axis, ascending=True)
#     - axis
#         - index명 기준 정렬(행) : 'index' 또는 0 (기본값)
#         - columnm 명 기준 정렬(열) : 'columns' 또는 1
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd

# %%
score_df=pd.read_csv('score3.csv')
score_df.sort_index(axis=1) #  axis=1: 컬럼명(열) 기준 오름차순 정렬
# Out:
#    eng    id  korean
# 0   90  id-1     100
# 1   80  id-2      50
# 2  100  id-3      70
# 3   50  id-4      60
# 4  100  id-5      90

# %%
score_df.sort_index(axis='columns',ascending=False)  # 내리차순
# Out:
#    korean    id  eng
# 0     100  id-1   90
# 1      50  id-2   80
# 2      70  id-3  100
# 3      60  id-4   50
# 4      90  id-5  100

# %%
s2=score_df.sort_index(ascending=False)  # axis=0(생략): index(행) 기준 내림차순 정렬
s2
# Out:
#      id  korean  eng
# 4  id-5      90  100
# 3  id-4      60   50
# 2  id-3      70  100
# 1  id-2      50   80
# 0  id-1     100   90

# %%
s2.sort_index()  # index기준으로 오름차순
# Out:
#      id  korean  eng
# 0  id-1     100   90
# 1  id-2      50   80
# 2  id-3      70  100
# 3  id-4      60   50
# 4  id-5      90  100

# %%
import pandas as pd
movie_df = pd.read_csv('data/movie.csv')
movie_df.shape
# Out:
# (4916, 28)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
# color                        4897 non-null object
# director_name                4814 non-null object
# num_critic_for_reviews       4867 non-null float64
# duration                     4901 non-null float64
# director_facebook_likes      4814 non-null float64
# actor_3_facebook_likes       4893 non-null float64
# actor_2_name                 4903 non-null object
# actor_1_facebook_likes       4909 non-null float64
# gross                        4054 non-null float64
# genres                       4916 non-null object
# actor_1_name                 4909 non-null object
# movie_title                  4916 non-null object
# num_voted_users              4916 non-null int64
# cast_total_facebook_likes    4916 non-null int64
# actor_3_name                 4893 non-null object
# facenumber_in_poster         4903 non-null float64
# ...

# %%
movie_df.set_index('movie_title')
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
movie_df.loc['A':'C']
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []
#
# [0 rows x 28 columns]

# %%
movie_df.sort_index().loc['A':'C']
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### 컬럼 값 기준 정렬
# - #### sort_values(by, ascending, inplace)
#     - by
#         - 정렬기준 컬럼명
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
movie_df.sort_values('director_name')
movie_df.sort_values('director_name', ascending=False)  # 내림차순
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 4731            Color       Étienne Faure                     9.0      98.0
# 4103            Color        Éric Tessier                     9.0      99.0
# 3609            Color    Émile Gaudreault                    67.0      92.0
# 3185            Color  Álex de la Iglesia                    71.0     104.0
# 4769            Color       Zoran Lisinac                    17.0     108.0
# 3502            Color      Zal Batmanglij                   200.0     116.0
# 4821            Color      Zal Batmanglij                   136.0      85.0
# 4354            Color            Zak Penn                    60.0      94.0
# 4126              NaN       Zackary Adler                    10.0     110.0
# 2431            Color           Zack Ward                    15.0      92.0
# 164             Color         Zack Snyder                   451.0     215.0
# ...

# %%
movie_df.sort_values(['duration', 'num_critic_for_reviews']).head(10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 1930  Color               NaN                    12.0       7.0
# 2316  Color        Jane Clark                     NaN       7.0
# 3997  Color               NaN                    38.0      11.0
# 4564  Color       Clark Baker                     1.0      14.0
# 4342  Color  Robert Greenwald                    56.0      20.0
# 749   Color               NaN                     8.0      22.0
# 4190  Color               NaN                     8.0      22.0
# 4688  Color               NaN                    11.0      22.0
# 807   Color               NaN                    20.0      22.0
# 824   Color               NaN                    26.0      22.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 1930                      NaN                     3.0        John Sparkes
# 2316                     23.0                    51.0     Traci Dinwiddie
# ...

# %%
movie_df.sort_values(['duration', 'num_critic_for_reviews'], ascending=[False,True]).head(10)
# 정렬 기준이 2개면 정렬방법도 순서에 맞춰 2개로 리스트 처리 (앞에 것이 우선)
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1694  Color                   NaN                    16.0     511.0
# 2436  Color                   NaN                   108.0     334.0
# 1487  Color       Taylor Hackford                    12.0     330.0
# 1134  Color        Michael Cimino                   102.0     325.0
# 3254  Color   Chatrichalerm Yukol                    31.0     300.0
# 2922  Color     Wolfgang Petersen                    96.0     293.0
# 1556  Color  Francis Ford Coppola                   261.0     289.0
# 2687  Color                   NaN                     9.0     286.0
# 874   Color           Ron Maxwell                    84.0     280.0
# 1963  Color           Ron Maxwell                    22.0     271.0
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 1694                      NaN                    51.0
# 2436                      NaN                    30.0
# ...

# %% [markdown]
# ## flights.csv (항공기 운항 기록)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일)
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
flight=pd.read_csv('data/flights.csv')
flight.shape
# Out:
# (58492, 14)

# %%
flight.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %% [markdown]
# ## 기술통계함수를 이용한 데이터 집계
# ### 주요 기술통계 함수
#
# |함수|설명|
# |-|-|
# |sum()|합계|
# |mean()|평균|
# |median()|중위수|
# |quantile()|분위수|
# |std()|표준편차|
# |var()|분산|
# |count()|결측치를 제외한 원소 개수|
# |min()|최소값|
# |max()|최대값|
# |idxmax()|최대값 index|
# |idxmin()|최소값 index|
# |unique()|고유값|
# |nunique()|고유값의 개수|
#
# - DataFrame에 적용할 경우 컬럼별로 계산
# - sum(), max(), min(), idxmax(), idxmin(), unique(), nunique(), count()는 문자열에 적용가능

# %%
movie_df.mean()  # DataFrame의 집계는 컬럼별로 구한다.
# Out:
# num_critic_for_reviews       1.379889e+02
# duration                     1.070908e+02
# director_facebook_likes      6.910145e+02
# actor_3_facebook_likes       6.312763e+02
# actor_1_facebook_likes       6.494488e+03
# gross                        4.764451e+07
# num_voted_users              8.264492e+04
# cast_total_facebook_likes    9.579816e+03
# facenumber_in_poster         1.377320e+00
# num_user_for_reviews         2.676688e+02
# budget                       3.654749e+07
# title_year                   2.002448e+03
# actor_2_facebook_likes       1.621924e+03
# imdb_score                   6.437429e+00
# aspect_ratio                 2.222349e+00
# movie_facebook_likes         7.348294e+03
# dtype: float64

# %%
movie_df.max()
# Out:
# num_critic_for_reviews       8.130000e+02
# duration                     5.110000e+02
# director_facebook_likes      2.300000e+04
# actor_3_facebook_likes       2.300000e+04
# actor_1_facebook_likes       6.400000e+05
# gross                        7.605058e+08
# num_voted_users              1.689764e+06
# cast_total_facebook_likes    6.567300e+05
# facenumber_in_poster         4.300000e+01
# num_user_for_reviews         5.060000e+03
# budget                       4.200000e+09
# title_year                   2.016000e+03
# actor_2_facebook_likes       1.370000e+05
# imdb_score                   9.500000e+00
# aspect_ratio                 1.600000e+01
# movie_facebook_likes         3.490000e+05
# dtype: float64

# %%
flight['ARR_DELAY'].mean(), flight['ARR_DELAY'].sum()
# Out:
# (5.812315133799631, 334057.0)

# %%
flight['AIRLINE'].mode()
# Out:
# 0    DL
# dtype: object

# %%
flight['AIRLINE'].nunique()
# Out:
# 14

# %%
flight['AIRLINE'].value_counts() # Series에만 있는 메소드
# Out:
# DL    10601
# AA     8900
# WN     8418
# UA     7792
# OO     6588
# EV     5858
# MQ     3471
# US     1615
# NK     1516
# F9     1317
# VX      993
# AS      768
# B6      543
# HA      112
# Name: AIRLINE, dtype: int64

# %% [markdown]
# ### aggregate(func, axis=0, \*args, \**kwargs) 또는 agg(func, axis=0, \*args, \**kwargs)
# - 판다스가 제공하는 집계 함수들이나 사용자 정의 집계함수를 DataFrame의 열 별로 처리해주는 함수.
# - **사용자 정의 집계함수를 사용하거나 열 별로 다른 집계를 할 때 사용한다.**
# - 매개변수
#     - func
#         - 집계 함수 지정
#             - 문자열/문자열리스트 : 집계함수의 이름. 여러 개일 경우 리스트. 판다스 제공 집계함수는 문자열로 함수명만 제공가능
#             - 딕션어리 : {집계할컬럼 : 집계함수 }
#             - 함수 객체 : 사용자 정의 함수의 경우 함수이름을 전달
#     - axis
#         - 0 또는 'index' (기본값): 컬럼 별 집계
#         - 1 또는 'columns': 행 별 집계
#     - \*args, \**kwargs
#         - 함수에 전달할 매개변수.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
flight['ARR_DELAY'].agg('mean'),flight['ARR_DELAY'].aggregate('sum')
# Out:
# (5.812315133799631, 334057.0)

# %%
flight.mean()
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
flight.agg(['mean','max','min']).T
# Out:
#                 mean   max  min
# MONTH        6.22065    12    1
# DAY          15.7021    31    1
# WEEKDAY      3.92686     7    1
# AIRLINE          NaN    WN   AA
# ORG_AIR          NaN   SFO  ATL
# DEST_AIR         NaN   YUM  ABE
# SCHED_DEP    1387.98  2359    5
# DEP_DELAY    10.9212  1194  -24
# AIR_TIME     115.929   577    8
# DIST           872.9  4502   67
# SCHED_ARR     1549.4  2359    1
# ARR_DELAY    5.81232  1185  -60
# DIVERTED   0.0023422     1    0
# CANCELLED  0.0150619     1    0

# %%
# 컬럼 별로 다른 집계를 한번에 처리
s_dict={'ARR_DELAY':['mean','sum'],'DEP_DELAY':['min','max']}
flight.agg(s_dict)
# Out:
#           ARR_DELAY  DEP_DELAY
# max             NaN     1194.0
# mean       5.812315        NaN
# min             NaN      -24.0
# sum   334057.000000        NaN

# %%
flight[['ARR_DELAY','DEP_DELAY']].agg(['mean','sum'])
# Out:
#           ARR_DELAY      DEP_DELAY
# mean       5.812315      10.921192
# sum   334057.000000  629705.000000

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 데이터셋을 묶는다.
# - ~~ 별 집계를 할 때 사용한다.
# - 구문
#     - DF.groupby('그룹으로묶을기준컬럼')['집계할 컬럼'].집계함수()
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %% [markdown]
# ###  복수열 기준 그룹핑
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %% [markdown]
# ## SQL having 처럼 집계한 것 중 특정 조건의 항목만 보기
# - boolean index과 동일한데 변수에 넣서 처리하는 것이 가독성이 좋다.

# %% [markdown]
# ## 사용자 정의 집계함수를 만들어 적용
# - 컴럼의 값들을 매개변수으로 받는다.
#     - Series 객체가 넘어온다.
# - 그외 인자가 있을 경우 첫번째 매개변수로 Series를 받고 나머지를 선언한다.
#     - agg(함수명, 전달인자, ..) : 두번째 매개변수 부터 순서대로 전달하거나 키워드 인자로 변수명=값으로 전달한다.

# %% [markdown]
# # TODO
# 1. data/diamonds.csv 를 읽어 DataFrame 생성
# 2. 1에서 생성한 dataframe의 정보 조회
#     - 배열의 shape조회
#     - 컬럼들의 정보조회
#     - 상/하위 5개 행 조회
# 3. cut별 가격 평균 조회
# 4. clarity별 carat 평균과 표준편차 조회
# 5. cut과 color 별로 가격은 평균을 carat은 최대값을 조회
